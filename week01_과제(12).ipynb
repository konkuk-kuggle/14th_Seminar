# %%
#시계열 데이터

# %%
#12-1 datetime 오브젝트

# %%
from datetime import datetime

# %%
nowl = datetime.now()
print(nowl)
# Out:
# 2026-09-07 20:17:36.981346

# %%
now2 = datetime.today()
print(now2)
# Out:
# 2026-09-07 20:18:34.617773

# %%
t1 = datetime.now()
t2 = datetime(1970, 1, 1)
t3 = datetime(1970, 12, 12, 13, 24, 34)

# %%
print(t1)
print(t2)
print(t3)
# Out:
# 2026-09-07 20:20:08.116527
# 1970-01-01 00:00:00
# 1970-12-12 13:24:34

# %%
diff1 = t1 - t2

print(diff1)
print(type(diff1))
# Out:
# 20703 days, 20:20:08.116527
# <class 'datetime.timedelta'>

# %%
diff2 = t2 - t1

print(diff2)
print(type(diff2))
# Out:
# -20704 days, 3:39:51.883473
# <class 'datetime.timedelta'>

# %%
# 문자열을 datetime 오브젝트로 변환하기

# %%
import pandas as pd
import os

ebola = pd.read_csv('../data/country_timeseries.csv')

# %%
print(ebola.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    str
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
#  15  Deaths_UnitedStates  18 non-null     float64
#  16  Deaths_Spain         16 non-null     float64
#  17  Deaths_Mali          12 non-null     float64
# dtypes: float64(16), int64(1), str(1)
# memory usage: 18.4 KB
# None

# %%
ebola['date_df'] = pd.to_datetime(ebola['Date'])
print(ebola.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    str
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
#  15  Deaths_UnitedStates  18 non-null     float64
#  16  Deaths_Spain         16 non-null     float64
#  17  Deaths_Mali          12 non-null     float64
#  18  date_df              122 non-null    datetime64[us]
# dtypes: datetime64[us](1), float64(16), int64(1), str(1)
# memory usage: 19.3 KB
# None

# %%
test_df1 = pd.DataFrame({'order_day':['01/01/15','02/01/15','03/01/15']})

# %%
test_df1['date_dt1'] = pd.to_datetime(test_df1['order_day'],format='%d/%m/%y')
test_df1['date_dt2'] = pd.to_datetime(test_df1['order_day'],format='%m/%d/%y')
test_df1['date_dt3'] = pd.to_datetime(test_df1['order_day'],format='%y/%m/%d')

# %%
print(test_df1)
# Out:
#   order_day   date_dt1   date_dt2  date_dt31
# 0  01/01/15 2015-01-01 2015-01-01 2001-01-15
# 1  02/01/15 2015-01-02 2015-02-01 2002-01-15
# 2  03/01/15 2015-01-03 2015-03-01 2003-01-15

# %%
#datetime 오브젝트로 변환하기-read_csv 메서드

# %%
ebola = pd.read_csv('../data/country_timeseries.csv', parse_dates=["Date"])
print(ebola.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[us]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
#  15  Deaths_UnitedStates  18 non-null     float64
#  16  Deaths_Spain         16 non-null     float64
#  17  Deaths_Mali          12 non-null     float64
# dtypes: datetime64[us](1), float64(16), int64(1)
# memory usage: 17.3 KB
# None

# %%
date_series = pd.Series(['2018-05-16','2018-05-17','2018-05-18'])
d1 = pd.to_datetime(date_series)
print(d1)
# Out:
# 0   2018-05-16
# 1   2018-05-17
# 2   2018-05-18
# dtype: datetime64[us]

# %%
print(d1[0].year)
# Out:
# 2018

# %%
print(d1[0].month)
# Out:
# 5

# %%
print(d1[0].day)
# Out:
# 16

# %%
#dt 접근자 사용하기

# %%
ebola = pd.read_csv('../data/country_timeseries.csv')
ebola['date_dt'] = pd.to_datetime(ebola['Date'])

# %%
print(ebola[['Date','date_dt']].head())
# Out:
#          Date    date_dt
# 0    1/5/2015 2015-01-05
# 1    1/4/2015 2015-01-04
# 2    1/3/2015 2015-01-03
# 3    1/2/2015 2015-01-02
# 4  12/31/2014 2014-12-31

# %%
print(ebola['date_dt'][3].year)
# Out:
# 2015

# %%
print(ebola['date_dt'][3].month)
# Out:
# 1

# %%
print(ebola['date_dt'][3].day)
# Out:
# 2

# %%
ebola['year'] = ebola['date_dt'].dt.year

# %%
print(ebola[['Date','date_dt','year']].head())
# Out:
#          Date    date_dt  year
# 0    1/5/2015 2015-01-05  2015
# 1    1/4/2015 2015-01-04  2015
# 2    1/3/2015 2015-01-03  2015
# 3    1/2/2015 2015-01-02  2015
# 4  12/31/2014 2014-12-31  2014

# %%
ebola['month'],ebola['day'] = (ebola['date_dt'].dt.month, ebola['date_dt'].dt.day)

# %%
print(ebola[['Date','date_dt','year','month','day']].head())
# Out:
#          Date    date_dt  year  month  day
# 0    1/5/2015 2015-01-05  2015      1    5
# 1    1/4/2015 2015-01-04  2015      1    4
# 2    1/3/2015 2015-01-03  2015      1    3
# 3    1/2/2015 2015-01-02  2015      1    2
# 4  12/31/2014 2014-12-31  2014     12   31

# %%
print(ebola.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    str
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
#  15  Deaths_UnitedStates  18 non-null     float64
#  16  Deaths_Spain         16 non-null     float64
#  17  Deaths_Mali          12 non-null     float64
#  18  date_dt              122 non-null    datetime64[us]
#  19  year                 122 non-null    int32
#  20  month                122 non-null    int32
#  21  day                  122 non-null    int32
# dtypes: datetime64[us](1), float64(16), int32(3), int64(1), str(1)
# memory usage: 20.7 KB
# None

# %%
#12-2 사례별 시계열 데이터

# %%
#에볼라 최초 발병일 계산하기

# %%
print(ebola.iloc[-5:,:5])
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 117  3/27/2014    5         103.0            8.0                6.0
# 118  3/26/2014    4          86.0            NaN                NaN
# 119  3/25/2014    3          86.0            NaN                NaN
# 120  3/24/2014    2          86.0            NaN                NaN
# 121  3/22/2014    0          49.0            NaN                NaN

# %%
print(ebola['date_dt'].min())
print(type(ebola['date_dt'].min()))
# Out:
# 2014-03-22 00:00:00
# <class 'pandas.Timestamp'>

# %%
#에볼라 진행 정도
ebola['outbreak_d'] = ebola['date_dt'] - ebola['date_dt'].min()
print(ebola[['Date','Day','outbreak_d']].head())
# Out:
#          Date  Day outbreak_d
# 0    1/5/2015  289   289 days
# 1    1/4/2015  288   288 days
# 2    1/3/2015  287   287 days
# 3    1/2/2015  286   286 days
# 4  12/31/2014  284   284 days

# %%
#파산한 은행의 개수 알아보기

# %%
banks = pd.read_csv('../data/banklist.csv')
print(banks.head())
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
#
#     CERT                Acquiring Institution Closing Date Updated Date
# 0   1802            United Fidelity Bank, fsb    26-May-17    26-Jul-17
# 1  30003  First-Citizens Bank & Trust Company     5-May-17    26-Jul-17
# 2  58302                         Whitney Bank    28-Apr-17    26-Jul-17
# 3  35495                    Cache Valley Bank     3-Mar-17    18-May-17
# 4  19328                  State Bank of Texas    27-Jan-17    18-May-17

# %%
banks_no_dates = pd.read_csv("../data/banklist.csv")
print(banks_no_dates.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bank Name              553 non-null    str
#  1   City                   553 non-null    str
#  2   ST                     553 non-null    str
#  3   CERT                   553 non-null    int64
#  4   Acquiring Institution  553 non-null    str
#  5   Closing Date           553 non-null    str
#  6   Updated Date           553 non-null    str
# dtypes: int64(1), str(6)
# memory usage: 68.2 KB
# None

# %%
banks = pd.read_csv(
    "../data/banklist.csv", parse_dates=["Closing Date", "Updated Date"]
)
print(banks.info())
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_24124\3460641572.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   banks = pd.read_csv(
# C:\Users\User\AppData\Local\Temp\ipykernel_24124\3460641572.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   banks = pd.read_csv(
# <class 'pandas.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bank Name              553 non-null    str
#  1   City                   553 non-null    str
#  2   ST                     553 non-null    str
#  3   CERT                   553 non-null    int64
#  4   Acquiring Institution  553 non-null    str
#  5   Closing Date           553 non-null    datetime64[us]
#  6   Updated Date           553 non-null    datetime64[us]
# dtypes: datetime64[us](2), int64(1), str(4)
# memory usage: 58.7 KB
# None

# %%
banks = banks.assign(
    closing_quarter=banks['Closing Date'].dt.quarter,
    closing_year=banks['Closing Date'].dt.year
)

# %%
closing_year = banks.groupby(['closing_year']).size()
print(closing_year)
# Out:
# closing_year
# 2000      2
# 2001      4
# 2002     11
# 2003      3
# 2004      4
# 2007      3
# 2008     25
# 2009    140
# 2010    157
# 2011     92
# 2012     51
# 2013     24
# 2014     18
# 2015      8
# 2016      5
# 2017      6
# dtype: int64

# %%
closing_year_q = (
    banks
    .groupby(['closing_year', 'closing_quarter'])
    .size()
)
print(closing_year_q)
# Out:
# closing_year  closing_quarter
# 2000          4                   2
# 2001          1                   1
#               2                   1
#               3                   2
# 2002          1                   6
#               2                   2
#               3                   1
#               4                   2
# 2003          1                   1
#               2                   1
#               4                   1
# 2004          1                   3
#               2                   1
# 2007          1                   1
#               3                   1
#               4                   1
# 2008          1                   2
#               2                   2
#               3                   9
#               4                  12
# 2009          1                  21
#               2                  24
#               3                  50
#               4                  45
# 2010          1                  41
#               2                  45
#               3                  41
#               4                  30
# 2011          1                  26
#               2                  22
#               3                  26
#               4                  18
# 2012          1                  16
#               2                  15
#               3                  12
#               4                   8
# 2013          1                   4
#               2                  12
#               3                   6
#               4                   2
# 2014          1                   5
#               2                   7
#               3                   2
#               4                   4
# 2015          1                   4
#               2                   1
#               3                   1
#               4                   2
# 2016          1                   1
#               2                   2
#               3                   2
# 2017          1                   3
#               2                   3
# dtype: int64

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax = closing_year.plot()
plt.show()
