# %% [markdown]
# # dtypes 속성으로 데이터프레임의 자료형 살펴보기

# %%
import pandas as pd
import seaborn as sns

tips = sns.load_dataset("tips")

# %% [markdown]
# # 여러 가지 자료형을 문자열로 변환하기

# %%
tips['sex_str'] = tips['sex'].astype(str)

# %%
print(tips.dtypes)
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# sex_str         object
# dtype: object

# %% [markdown]
# # 자료형을 변환한 데이터 다시 원래대로 만들기

# %%
tips['total_bill'] = tips['total_bill'].astype(str)
print(tips.dtypes)

tips['total_bill'] = tips['total_bill'].astype(float)
print(tips.dtypes)
# Out:
# total_bill      object
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# sex_str         object
# dtype: object
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# sex_str         object
# dtype: object

# %% [markdown]
# # 잘못 입력한 문자열 처리하기

# %%
tips_sub_miss = tips.head(10)
tips_sub_miss.loc[[1, 3, 5, 7], 'total_bill'] = 'missing'
print(tips_sub_miss)
# Out:
#   total_bill   tip     sex smoker  day    time  size sex_str
# 0      16.99  1.01  Female     No  Sun  Dinner     2  Female
# 1    missing  1.66    Male     No  Sun  Dinner     3    Male
# 2      21.01  3.50    Male     No  Sun  Dinner     3    Male
# 3    missing  3.31    Male     No  Sun  Dinner     2    Male
# 4      24.59  3.61  Female     No  Sun  Dinner     4  Female
# 5    missing  4.71    Male     No  Sun  Dinner     4    Male
# 6       8.77  2.00    Male     No  Sun  Dinner     2    Male
# 7    missing  3.12    Male     No  Sun  Dinner     4    Male
# 8      15.04  1.96    Male     No  Sun  Dinner     2    Male
# 9      14.78  3.23    Male     No  Sun  Dinner     2    Male
# C:\Users\meaty\AppData\Local\Temp\ipykernel_32192\638463016.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'missing' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   tips_sub_miss.loc[[1, 3, 5, 7], 'total_bill'] = 'missing'

# %%
print(tips_sub_miss.dtype)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(tips_sub_miss.dtype)
#
# NameError: name 'tips_sub_miss' is not defined

# %%
tips_sub_miss['total_bill'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 tips_sub_miss['total_bill'].astype(float)
#
# NameError: name 'tips_sub_miss' is not defined

# %%
pd.to_numeric(tips_sub_miss['total_bill'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pd.to_numeric(tips_sub_miss['total_bill'])
#
# NameError: name 'tips_sub_miss' is not defined

# %%
tips_sub_miss['total_bill'] = pd.to_numeric(tips_sub_miss['total_bill'],
errors='ignore')
print(tips_sub__miss.dtypes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 tips_sub_miss['total_bill'] = pd.to_numeric(tips_sub_miss['total_bill'],
#       2 errors='ignore')
#       3 print(tips_sub__miss.dtypes)
#
# NameError: name 'tips_sub_miss' is not defined

# %%
tips_sub_miss['total_bill'] = pd.to_numeric(tips_sub_miss['total_bill'],
                                            errors='coerce')
print(tips_sub_miss.dtypes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 tips_sub_miss['total_bill'] = pd.to_numeric(tips_sub_miss['total_bill'],
#       2                                             errors='coerce')
#       3 print(tips_sub_miss.dtypes)
#
# NameError: name 'tips_sub_miss' is not defined

# %%
tips_sub_miss['total_bill'] = pd.to_numeric(tips_sub_miss['total_bill'],
errors='coerce', downcast+'float')

print(tips_sub_miss.dtypes)
# Out:
#   Cell In[15], line 2
#     errors='coerce', downcast+'float')
#                                      ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# # 문자열을 카테고리로 변환하기

# %%
tips['sex'] = tips['sex'].astype('str')
print(tips.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(3), float64(2), int64(1), object(1)
# memory usage: 8.9+ KB
# None

# %%
tips['sex'] = tips['sex'].astype('category')
print(tips.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None
