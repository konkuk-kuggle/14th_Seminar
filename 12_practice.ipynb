# %% [markdown]
# # datetime 오브젝트 사용하기

# %%
from datetime import datetime

# %%
now1=datetime.now()
print(now1)
# Out:
# 2026-09-08 13:57:23.117917

# %%
now2=datetime.now()
print(now2)
# Out:
# 2026-09-08 13:57:37.292506

# %%
t1=datetime.now()
t2=datetime(1970, 1, 1)
t3=datetime(1970, 12, 12, 13, 24, 34)

print(t1)
print(t2)
print(t3)
# Out:
# 2026-09-08 13:58:26.275862
# 1970-01-01 00:00:00
# 1970-12-12 13:24:34

# %%
diff1= t1-t2

print(diff1)
print(type(diff1))
# Out:
# 20704 days, 13:58:26.275862
# <class 'datetime.timedelta'>

# %%
diff2= t2-t1

print(diff2)
print(type(diff2))
# Out:
# -20705 days, 10:01:33.724138
# <class 'datetime.timedelta'>

# %% [markdown]
# # 문자열을 datetime 오브젝트로 변환하기

# %%
import pandas as pd
import os

ebola =pd.read_csv('../data/country_timeseries.csv')

# %%
print(ebola.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    str
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
#  15  Deaths_UnitedStates  18 non-null     float64
#  16  Deaths_Spain         16 non-null     float64
#  17  Deaths_Mali          12 non-null     float64
# dtypes: float64(16), int64(1), str(1)
# memory usage: 18.4 KB
# None

# %%
ebola['date_dt']=pd.to_datetime(ebola['Date'])
print(ebola.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    str
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
#  15  Deaths_UnitedStates  18 non-null     float64
#  16  Deaths_Spain         16 non-null     float64
#  17  Deaths_Mali          12 non-null     float64
#  18  date_dt              122 non-null    datetime64[us]
# dtypes: datetime64[us](1), float64(16), int64(1), str(1)
# memory usage: 19.3 KB
# None

# %%
test_df1=pd.DataFrame({'order_dat':['01/01/15', '02/01/15', '03/01/15']})

test_df1['date_dt1']=pd.to_datetime(test_df1['order_dat'], format='%d/%m/%y')
test_df1['date_dt2']=pd.to_datetime(test_df1['order_dat'], format='%m/%d/%y')
test_df1['date_dt3']=pd.to_datetime(test_df1['order_dat'], format='%y/%m/%d')

print(test_df1)
# Out:
#   order_dat   date_dt1   date_dt2   date_dt3
# 0  01/01/15 2015-01-01 2015-01-01 2001-01-15
# 1  02/01/15 2015-01-02 2015-02-01 2002-01-15
# 2  03/01/15 2015-01-03 2015-03-01 2003-01-15

# %%
test_df2=pd.DataFrame({'order_day':['01-01-15', '02-01-15', '03-01-15']})
test_df2['date_dt']=pd.to_datetime(test_df2['order_day'], format='%d-%m-%y')

print(test_df2)
# Out:
#   order_day    date_dt
# 0  01-01-15 2015-01-01
# 1  02-01-15 2015-01-02
# 2  03-01-15 2015-01-03

# %% [markdown]
# # 시간 데이터를 잘라내고 싶어요

# %%
now=datetime.now()
print(now)
# Out:
# 2026-09-08 14:05:48.512430

# %%
nowDate=now.strftime('%y-%m-%d')
print(nowDate)
# Out:
# 26-09-08

# %%
nowTime=now.strftime('%H:"M:%S')
print(nowTime)
# Out:
# 14:"M:48

# %%
nowDatetime=now.strftime('%Y-%m-%d %H: %M: %S')
print(nowDatetime)
# Out:
# 2026-09-08 14: 05: 48

# %% [markdown]
# # datetime 오브젝트로 변환하려는 열을 지정하여 데이터 집합 불러오기

# %%
ebola1=pd.read_csv('../data/country_timeseries.csv', parse_dates=['Date'])
print(ebola1.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[us]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
#  15  Deaths_UnitedStates  18 non-null     float64
#  16  Deaths_Spain         16 non-null     float64
#  17  Deaths_Mali          12 non-null     float64
# dtypes: datetime64[us](1), float64(16), int64(1)
# memory usage: 17.3 KB
# None

# %% [markdown]
# # datetime 오브젝트에서 날짜 정보 추출하기

# %%
date_series=pd.Series(['2018-05-16', '2018-05-17', '2018-05-18'])
d1=pd.to_datetime(date_series)
print(d1)
# Out:
# 0   2018-05-16
# 1   2018-05-17
# 2   2018-05-18
# dtype: datetime64[us]

# %%
print(d1[0].year)

print(d1[0].month)

print(d1[0].day)
# Out:
# 2018
# 5
# 16

# %% [markdown]
# # dt 접근자로 시간 데이터 정리하기

# %%
ebola=pd.read_csv('../data/country_timeseries.csv')
ebola['date_dt']=pd.to_datetime(ebola['Date'])

# %%
print(ebola[['Date', 'date_dt']].head())

print(ebola['date_dt'][3].year)
# Out:
#          Date    date_dt
# 0    1/5/2015 2015-01-05
# 1    1/4/2015 2015-01-04
# 2    1/3/2015 2015-01-03
# 3    1/2/2015 2015-01-02
# 4  12/31/2014 2014-12-31
# 2015

# %%
print(ebola['date_dt'][3].month)
# Out:
# 1

# %%
print(ebola['date_dt'][3].day)
# Out:
# 2

# %%
ebola['year']=ebola['date_dt'].dt.year

print(ebola[['Date', 'date_dt', 'year']].head())
# Out:
#          Date    date_dt  year
# 0    1/5/2015 2015-01-05  2015
# 1    1/4/2015 2015-01-04  2015
# 2    1/3/2015 2015-01-03  2015
# 3    1/2/2015 2015-01-02  2015
# 4  12/31/2014 2014-12-31  2014

# %%
ebola['month'], ebola['day']=(ebola['date_dt'].dt.month, ebola['date_dt'].dt.day)

print(ebola[['Date', 'date_dt', 'year','month','day']].head())
# Out:
#          Date    date_dt  year  month  day
# 0    1/5/2015 2015-01-05  2015      1    5
# 1    1/4/2015 2015-01-04  2015      1    4
# 2    1/3/2015 2015-01-03  2015      1    3
# 3    1/2/2015 2015-01-02  2015      1    2
# 4  12/31/2014 2014-12-31  2014     12   31

# %%
print(ebola.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    str
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
#  15  Deaths_UnitedStates  18 non-null     float64
#  16  Deaths_Spain         16 non-null     float64
#  17  Deaths_Mali          12 non-null     float64
#  18  date_dt              122 non-null    datetime64[us]
#  19  year                 122 non-null    int32
#  20  month                122 non-null    int32
#  21  day                  122 non-null    int32
# dtypes: datetime64[us](1), float64(16), int32(3), int64(1), str(1)
# memory usage: 20.7 KB
# None

# %% [markdown]
# # 에볼라 최초 발생일 계산해보기

# %%
print(ebola.iloc[-5:, :5])
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 117  3/27/2014    5         103.0            8.0                6.0
# 118  3/26/2014    4          86.0            NaN                NaN
# 119  3/25/2014    3          86.0            NaN                NaN
# 120  3/24/2014    2          86.0            NaN                NaN
# 121  3/22/2014    0          49.0            NaN                NaN

# %%
print(ebola['date_dt'].min())
print(type(ebola['date_dt'].min()))
# Out:
# 2014-03-22 00:00:00
# <class 'pandas.Timestamp'>

# %%
ebola['outbreak_d']=ebola['date_dt']-ebola['date_dt'].min()

print(ebola[['Date','Day','outbreak_d']].head())
# Out:
#          Date  Day outbreak_d
# 0    1/5/2015  289   289 days
# 1    1/4/2015  288   288 days
# 2    1/3/2015  287   287 days
# 3    1/2/2015  286   286 days
# 4  12/31/2014  284   284 days

# %% [markdown]
# # 파산한 은행의 개수 계산하기

# %%
banks=pd.read_csv('../data/banklist.csv')
print(banks.head())
# Out:
#                                            Bank Name         City  ST   CERT  \
# 0                Washington Federal Bank for Savings      Chicago  IL  30570
# 1    The Farmers and Merchants State Bank of Argonia      Argonia  KS  17719
# 2                                Fayette County Bank   Saint Elmo  IL   1802
# 3  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI  30003
# 4                                     First NBC Bank  New Orleans  LA  58302
#
#                  Acquiring Institution Closing Date Updated Date
# 0                   Royal Savings Bank    15-Dec-17    20-Dec-17
# 1                          Conway Bank    13-Oct-17    20-Oct-17
# 2            United Fidelity Bank, fsb    26-May-17    26-Jul-17
# 3  First-Citizens Bank & Trust Company     5-May-17    26-Jul-17
# 4                         Whitney Bank    28-Apr-17     5-Dec-17

# %%
banks_no_dates=pd.read_csv('../data/banklist.csv')
print(banks_no_dates.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 555 entries, 0 to 554
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bank Name              555 non-null    str
#  1   City                   555 non-null    str
#  2   ST                     555 non-null    str
#  3   CERT                   555 non-null    int64
#  4   Acquiring Institution  555 non-null    str
#  5   Closing Date           555 non-null    str
#  6   Updated Date           555 non-null    str
# dtypes: int64(1), str(6)
# memory usage: 68.4 KB
# None

# %%
banks=pd.read_csv('../data/banklist.csv', parse_dates=[5,6])
print(banks.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 555 entries, 0 to 554
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bank Name              555 non-null    str
#  1   City                   555 non-null    str
#  2   ST                     555 non-null    str
#  3   CERT                   555 non-null    int64
#  4   Acquiring Institution  555 non-null    str
#  5   Closing Date           555 non-null    datetime64[us]
#  6   Updated Date           555 non-null    datetime64[us]
# dtypes: datetime64[us](2), int64(1), str(4)
# memory usage: 58.9 KB
# None
# C:\Users\brady\AppData\Local\Temp\ipykernel_19488\1741722131.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   banks=pd.read_csv('../data/banklist.csv', parse_dates=[5,6])
# C:\Users\brady\AppData\Local\Temp\ipykernel_19488\1741722131.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   banks=pd.read_csv('../data/banklist.csv', parse_dates=[5,6])

# %%
banks['closing_quarter'], banks['closing_year']=(banks['Closing Date'].
    dt.quarter, banks['Closing Date'].dt.year)

print(banks.head())
# Out:
#                                            Bank Name         City  ST   CERT  \
# 0                Washington Federal Bank for Savings      Chicago  IL  30570
# 1    The Farmers and Merchants State Bank of Argonia      Argonia  KS  17719
# 2                                Fayette County Bank   Saint Elmo  IL   1802
# 3  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI  30003
# 4                                     First NBC Bank  New Orleans  LA  58302
#
#                  Acquiring Institution Closing Date Updated Date  \
# 0                   Royal Savings Bank   2017-12-15   2017-12-20
# 1                          Conway Bank   2017-10-13   2017-10-20
# 2            United Fidelity Bank, fsb   2017-05-26   2017-07-26
# 3  First-Citizens Bank & Trust Company   2017-05-05   2017-07-26
# 4                         Whitney Bank   2017-04-28   2017-12-05
#
#    closing_quarter  closing_year
# 0                4          2017
# 1                4          2017
# 2                2          2017
# 3                2          2017
# 4                2          2017

# %%
closing_year=banks.groupby(['closing_year']).size()
print(closing_year)
# Out:
# closing_year
# 2000      2
# 2001      4
# 2002     11
# 2003      3
# 2004      4
# 2007      3
# 2008     25
# 2009    140
# 2010    157
# 2011     92
# 2012     51
# 2013     24
# 2014     18
# 2015      8
# 2016      5
# 2017      8
# dtype: int64

# %%
closing_year_q=banks.groupby(['closing_year','closing_quarter']).size()
print(closing_year_q)
# Out:
# closing_year  closing_quarter
# 2000          4                   2
# 2001          1                   1
#               2                   1
#               3                   2
# 2002          1                   6
#               2                   2
#               3                   1
#               4                   2
# 2003          1                   1
#               2                   1
#               4                   1
# 2004          1                   3
#               2                   1
# 2007          1                   1
#               3                   1
#               4                   1
# 2008          1                   2
#               2                   2
#               3                   9
#               4                  12
# 2009          1                  21
#               2                  24
#               3                  50
#               4                  45
# 2010          1                  41
#               2                  45
#               3                  41
#               4                  30
# 2011          1                  26
#               2                  22
#               3                  26
#               4                  18
# 2012          1                  16
#               2                  15
#               3                  12
#               4                   8
# 2013          1                   4
#               2                  12
#               3                   6
#               4                   2
# 2014          1                   5
#               2                   7
#               3                   2
#               4                   4
# 2015          1                   4
#               2                   1
#               3                   1
#               4                   2
# 2016          1                   1
#               2                   2
#               3                   2
# 2017          1                   3
#               2                   3
#               4                   2
# dtype: int64

# %%
import matplotlib.pyplot as plt

fly, ax=plt.subplots()

zx=closing_year.plot

plt.show()

# %%
fig, ax=plt.subplots()
ax=closing_year_q.plot()
plt.show()

# %% [markdown]
# # 테슬라 주식 데이터로 시간 계산하기

# %%
pip install pandas-datareader
# Out:
# Collecting pandas-datareader
#   Downloading pandas_datareader-0.11.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting lxml (from pandas-datareader)
#   Downloading lxml-6.1.3-cp314-cp314-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: pandas>=2.1.4 in C:\Users\brady\anaconda3\Lib\site-packages (from pandas-datareader) (3.0.3)
# Requirement already satisfied: requests>=2.19.0 in C:\Users\brady\anaconda3\Lib\site-packages (from pandas-datareader) (2.34.2)
# Requirement already satisfied: setuptools in C:\Users\brady\anaconda3\Lib\site-packages (from pandas-datareader) (83.0.0)
# Requirement already satisfied: numpy>=2.3.3 in C:\Users\brady\anaconda3\Lib\site-packages (from pandas>=2.1.4->pandas-datareader) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\brady\anaconda3\Lib\site-packages (from pandas>=2.1.4->pandas-datareader) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\brady\anaconda3\Lib\site-packages (from pandas>=2.1.4->pandas-datareader) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\brady\anaconda3\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.1.4->pandas-datareader) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\brady\anaconda3\Lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\brady\anaconda3\Lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\brady\anaconda3\Lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\brady\anaconda3\Lib\site-packages (from requests>=2.19.0->pandas-datareader) (2026.6.17)
# Downloading pandas_datareader-0.11.1-py3-none-any.whl (65 kB)
# Downloading lxml-6.1.3-cp314-cp314-win_amd64.whl (4.1 MB)
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.1 MB 252.1 kB/s eta 0:00:15
#    ----- ---------------------------------- 0.5/4.1 MB 252.1 kB/s eta 0:00:15
#    ----- ---------------------------------- 0.5/4.1 MB 252.1 kB/s eta 0:00:15
#    ----- ---------------------------------- 0.5/4.1 MB 252.1 kB/s eta 0:00:15
#    ----- ---------------------------------- 0.5/4.1 MB 252.1 kB/s eta 0:00:15
#    ----- ---------------------------------- 0.5/4.1 MB 252.1 kB/s eta 0:00:15
#    ------- -------------------------------- 0.8/4.1 MB 221.3 kB/s eta 0:00:15
#    ------- -------------------------------- 0.8/4.1 MB 221.3 kB/s eta 0:00:15
#    ------- -------------------------------- 0.8/4.1 MB 221.3 kB/s eta 0:00:15
#    ------- -------------------------------- 0.8/4.1 MB 221.3 kB/s eta 0:00:15
#    ------- -------------------------------- 0.8/4.1 MB 221.3 kB/s eta 0:00:15
#    ---------- ----------------------------- 1.0/4.1 MB 224.0 kB/s eta 0:00:14
#    ---------- ----------------------------- 1.0/4.1 MB 224.0 kB/s eta 0:00:14
#    ---------- ----------------------------- 1.0/4.1 MB 224.0 kB/s eta 0:00:14
#    ---------- ----------------------------- 1.0/4.1 MB 224.0 kB/s eta 0:00:14
#    ---------- ----------------------------- 1.0/4.1 MB 224.0 kB/s eta 0:00:14
#    ---------- ----------------------------- 1.0/4.1 MB 224.0 kB/s eta 0:00:14
#    ------------ --------------------------- 1.3/4.1 MB 226.1 kB/s eta 0:00:13
#    ------------ --------------------------- 1.3/4.1 MB 226.1 kB/s eta 0:00:13
#    ------------ --------------------------- 1.3/4.1 MB 226.1 kB/s eta 0:00:13
#    ------------ --------------------------- 1.3/4.1 MB 226.1 kB/s eta 0:00:13
#    --------------- ------------------------ 1.6/4.1 MB 241.2 kB/s eta 0:00:11
#    --------------- ------------------------ 1.6/4.1 MB 241.2 kB/s eta 0:00:11
#    --------------- ------------------------ 1.6/4.1 MB 241.2 kB/s eta 0:00:11
#    --------------- ------------------------ 1.6/4.1 MB 241.2 kB/s eta 0:00:11
#    ------------------ --------------------- 1.8/4.1 MB 251.2 kB/s eta 0:00:09
#    ------------------ --------------------- 1.8/4.1 MB 251.2 kB/s eta 0:00:09
#    ------------------ --------------------- 1.8/4.1 MB 251.2 kB/s eta 0:00:09
#    ------------------ --------------------- 1.8/4.1 MB 251.2 kB/s eta 0:00:09
#    -------------------- ------------------- 2.1/4.1 MB 254.6 kB/s eta 0:00:08
#    -------------------- ------------------- 2.1/4.1 MB 254.6 kB/s eta 0:00:08
#    -------------------- ------------------- 2.1/4.1 MB 254.6 kB/s eta 0:00:08
#    -------------------- ------------------- 2.1/4.1 MB 254.6 kB/s eta 0:00:08
#    ----------------------- ---------------- 2.4/4.1 MB 261.9 kB/s eta 0:00:07
#    ----------------------- ---------------- 2.4/4.1 MB 261.9 kB/s eta 0:00:07
#    ----------------------- ---------------- 2.4/4.1 MB 261.9 kB/s eta 0:00:07
#    ----------------------- ---------------- 2.4/4.1 MB 261.9 kB/s eta 0:00:07
#    ------------------------- -------------- 2.6/4.1 MB 267.5 kB/s eta 0:00:06
#    ------------------------- -------------- 2.6/4.1 MB 267.5 kB/s eta 0:00:06
#    ------------------------- -------------- 2.6/4.1 MB 267.5 kB/s eta 0:00:06
#    ------------------------- -------------- 2.6/4.1 MB 267.5 kB/s eta 0:00:06
#    ---------------------------- ----------- 2.9/4.1 MB 272.3 kB/s eta 0:00:05
#    ---------------------------- ----------- 2.9/4.1 MB 272.3 kB/s eta 0:00:05
#    ---------------------------- ----------- 2.9/4.1 MB 272.3 kB/s eta 0:00:05
#    ---------------------------- ----------- 2.9/4.1 MB 272.3 kB/s eta 0:00:05
#    ---------------------------- ----------- 2.9/4.1 MB 272.3 kB/s eta 0:00:05
#    ---------------------------- ----------- 2.9/4.1 MB 272.3 kB/s eta 0:00:05
#    ---------------------------- ----------- 2.9/4.1 MB 272.3 kB/s eta 0:00:05
#    ------------------------------ --------- 3.1/4.1 MB 258.0 kB/s eta 0:00:04
#    ------------------------------ --------- 3.1/4.1 MB 258.0 kB/s eta 0:00:04
#    ------------------------------ --------- 3.1/4.1 MB 258.0 kB/s eta 0:00:04
#    ------------------------------ --------- 3.1/4.1 MB 258.0 kB/s eta 0:00:04
#    ------------------------------ --------- 3.1/4.1 MB 258.0 kB/s eta 0:00:04
#    ------------------------------ --------- 3.1/4.1 MB 258.0 kB/s eta 0:00:04
#    ------------------------------ --------- 3.1/4.1 MB 258.0 kB/s eta 0:00:04
#    --------------------------------- ------ 3.4/4.1 MB 247.5 kB/s eta 0:00:03
#    --------------------------------- ------ 3.4/4.1 MB 247.5 kB/s eta 0:00:03
#    --------------------------------- ------ 3.4/4.1 MB 247.5 kB/s eta 0:00:03
#    --------------------------------- ------ 3.4/4.1 MB 247.5 kB/s eta 0:00:03
#    --------------------------------- ------ 3.4/4.1 MB 247.5 kB/s eta 0:00:03
#    --------------------------------- ------ 3.4/4.1 MB 247.5 kB/s eta 0:00:03
#    --------------------------------- ------ 3.4/4.1 MB 247.5 kB/s eta 0:00:03
#    ------------------------------------ --- 3.7/4.1 MB 242.8 kB/s eta 0:00:02
#    ------------------------------------ --- 3.7/4.1 MB 242.8 kB/s eta 0:00:02
#    ------------------------------------ --- 3.7/4.1 MB 242.8 kB/s eta 0:00:02
#    ------------------------------------ --- 3.7/4.1 MB 242.8 kB/s eta 0:00:02
#    ------------------------------------ --- 3.7/4.1 MB 242.8 kB/s eta 0:00:02
#    ------------------------------------ --- 3.7/4.1 MB 242.8 kB/s eta 0:00:02
#    ------------------------------------ --- 3.7/4.1 MB 242.8 kB/s eta 0:00:02
#    ------------------------------------ --- 3.7/4.1 MB 242.8 kB/s eta 0:00:02
#    ------------------------------------ --- 3.7/4.1 MB 242.8 kB/s eta 0:00:02
#    -------------------------------------- - 3.9/4.1 MB 229.6 kB/s eta 0:00:01
#    -------------------------------------- - 3.9/4.1 MB 229.6 kB/s eta 0:00:01
#    -------------------------------------- - 3.9/4.1 MB 229.6 kB/s eta 0:00:01
#    -------------------------------------- - 3.9/4.1 MB 229.6 kB/s eta 0:00:01
#    -------------------------------------- - 3.9/4.1 MB 229.6 kB/s eta 0:00:01
#    -------------------------------------- - 3.9/4.1 MB 229.6 kB/s eta 0:00:01
#    -------------------------------------- - 3.9/4.1 MB 229.6 kB/s eta 0:00:01
#    -------------------------------------- - 3.9/4.1 MB 229.6 kB/s eta 0:00:01
#    -------------------------------------- - 3.9/4.1 MB 229.6 kB/s eta 0:00:01
#    ---------------------------------------- 4.1/4.1 MB 214.4 kB/s  0:00:19
# Installing collected packages: lxml, pandas-datareader
#
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    -------------------- ------------------- 1/2 [pandas-datareader]
#    -------------------- ------------------- 1/2 [pandas-datareader]
#    ---------------------------------------- 2/2 [pandas-datareader]
#
# Successfully installed lxml-6.1.3 pandas-datareader-0.11.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.core.common.is_list_like=pd.api.types.is_list_like
import pandas_datareader as pdr

tesla=pdr.get_data_quandl('TSLA', api_key='받은 key')

tesla.to_csv('../data/tesla_stock_quandl.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 4
#       1 pd.core.common.is_list_like=pd.api.types.is_list_like
#       2 import pandas_datareader as pdr
#       3
# ----> 4 tesla=pdr.get_data_quandl('TSLA', api_key='받은 key')
#       5
#       6 tesla.to_csv('../data/tesla_stock_quandl.csv')
#
# AttributeError: module 'pandas_datareader' has no attribute 'get_data_quandl'

# %%
print(tesla.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 print(tesla.head())
#
# NameError: name 'tesla' is not defined

# %% [markdown]
# # datetime 오브젝트를 인덱스로 설정하여 데이터 추출하기

# %%
tesla.index=tesla['Date']
print(tesla.index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 tesla.index=tesla['Date']
#       2 print(tesla.index)
#
# NameError: name 'tesla' is not defined

# %%
print(tesla['2015'].iloc[:5, :5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 print(tesla['2015'].iloc[:5, :5])
#
# NameError: name 'tesla' is not defined

# %%
print(tesla['2010-06'].iloc[:, :5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 print(tesla['2010-06'].iloc[:, :5])
#
# NameError: name 'tesla' is not defined

# %% [markdown]
# # 시간 간격을 인덱스로 설정하여 데이터 추출하기

# %%
tesla['ref_date']=tesla['Date']-tesla['Date'].min()
print(tesla.head)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 tesla['ref_date']=tesla['Date']-tesla['Date'].min()
#       2 print(tesla.head)
#
# NameError: name 'tesla' is not defined

# %% [markdown]
# # 시간 범위 생성하여 인덱스로 지정하기

# %%
ebola=pd.read_csv('../data/country_timeseries.csv', parse_dates=[0])
print(ebola.iloc[:5, :5])
# Out:
#         Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 0 2015-01-05  289        2776.0            NaN            10030.0
# 1 2015-01-04  288        2775.0            NaN             9780.0
# 2 2015-01-03  287        2769.0         8166.0             9722.0
# 3 2015-01-02  286           NaN         8157.0                NaN
# 4 2014-12-31  284        2730.0         8115.0             9633.0

# %%
print(ebola.iloc[-5:, :5])
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN

# %%
head_range=pd.date_range(start='2014-12-31', end='2015-01-05')
print(head_range)
# Out:
# DatetimeIndex(['2014-12-31', '2015-01-01', '2015-01-02', '2015-01-03',
#                '2015-01-04', '2015-01-05'],
#               dtype='datetime64[us]', freq='D')

# %%
ebola_5=ebola.head()
ebola_5.index=ebola_5['Date']
ebola_5.reindex(head_range)
print(ebola_5.iloc[:5, :5])
# Out:
#                  Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# Date
# 2015-01-05 2015-01-05  289        2776.0            NaN            10030.0
# 2015-01-04 2015-01-04  288        2775.0            NaN             9780.0
# 2015-01-03 2015-01-03  287        2769.0         8166.0             9722.0
# 2015-01-02 2015-01-02  286           NaN         8157.0                NaN
# 2014-12-31 2014-12-31  284        2730.0         8115.0             9633.0

# %% [markdown]
# # 시간 범위의 주기 설정하기

# %%
import matplotlib.pyplot as plt

ebola.index=ebola['Date']

fig, ax=plt.subplots()
ax=ebola.iloc[0:, 1:].plot(ax=ax)
ax.legend(fontsize=7, loc=2, borderaxespad=0.)
plt.show()

# %%
ebola_sub=ebola[['Day', 'Cases_Guinea', 'Cases_Liberia']]
print(ebola_sub.tail(10))
# Out:
#             Day  Cases_Guinea  Cases_Liberia
# Date
# 2014-04-04   13         143.0           18.0
# 2014-04-01   10         127.0            8.0
# 2014-03-31    9         122.0            8.0
# 2014-03-29    7         112.0            7.0
# 2014-03-28    6         112.0            3.0
# 2014-03-27    5         103.0            8.0
# 2014-03-26    4          86.0            NaN
# 2014-03-25    3          86.0            NaN
# 2014-03-24    2          86.0            NaN
# 2014-03-22    0          49.0            NaN

# %%
ebola=pd.read_csv('../data/country_timeseries.csv', parse_dates=['Date'])

print(ebola.head().iloc[:, :5])
# Out:
#         Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 0 2015-01-05  289        2776.0            NaN            10030.0
# 1 2015-01-04  288        2775.0            NaN             9780.0
# 2 2015-01-03  287        2769.0         8166.0             9722.0
# 3 2015-01-02  286           NaN         8157.0                NaN
# 4 2014-12-31  284        2730.0         8115.0             9633.0

# %%
print(ebola.tail().iloc[:, :5])
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN

# %%
ebola.index=ebola['Date']
new_idx=pd.date_range(ebola.index.min(), ebola.index.max())

# %%
print(new_idx)
# Out:
# DatetimeIndex(['2014-03-22', '2014-03-23', '2014-03-24', '2014-03-25',
#                '2014-03-26', '2014-03-27', '2014-03-28', '2014-03-29',
#                '2014-03-30', '2014-03-31',
#                ...
#                '2014-12-27', '2014-12-28', '2014-12-29', '2014-12-30',
#                '2014-12-31', '2015-01-01', '2015-01-02', '2015-01-03',
#                '2015-01-04', '2015-01-05'],
#               dtype='datetime64[us]', length=290, freq='D')

# %%
ebola=ebola.reindex(new_idx)

print(ebola.head().iloc[:, :5])
# Out:
#                  Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 2014-03-22 2014-03-22  0.0          49.0            NaN                NaN
# 2014-03-23        NaT  NaN           NaN            NaN                NaN
# 2014-03-24 2014-03-24  2.0          86.0            NaN                NaN
# 2014-03-25 2014-03-25  3.0          86.0            NaN                NaN
# 2014-03-26 2014-03-26  4.0          86.0            NaN                NaN

# %%
print(ebola.tail().iloc[:, :5])
# Out:
#                  Date    Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 2015-01-01        NaT    NaN           NaN            NaN                NaN
# 2015-01-02 2015-01-02  286.0           NaN         8157.0                NaN
# 2015-01-03 2015-01-03  287.0        2769.0         8166.0             9722.0
# 2015-01-04 2015-01-04  288.0        2775.0            NaN             9780.0
# 2015-01-05 2015-01-05  289.0        2776.0            NaN            10030.0

# %% [markdown]
# # 에볼라 발병 시간 비교하기

# %%
last_valid=ebola.apply(pd.Series.last_valid_index)
print(last_valid)

# %%
earliest_date=ebola.index.min()
print(earliest_date)

shift_values=last_valid-earliest_date
print(shift_values)
# Out:
# 2014-03-22 00:00:00
# Date                  289 days
# Day                   289 days
# Cases_Guinea          289 days
# Cases_Liberia         287 days
# Cases_SierraLeone     289 days
# Cases_Nigeria         260 days
# Cases_Senegal         260 days
# Cases_UnitedStates    260 days
# Cases_Spain           260 days
# Cases_Mali            260 days
# Deaths_Guinea         289 days
# Deaths_Liberia        287 days
# Deaths_SierraLeone    289 days
# Deaths_Nigeria        260 days
# Deaths_Senegal        260 days
# Deaths_UnitedStates   260 days
# Deaths_Spain          260 days
# Deaths_Mali           260 days
# dtype: timedelta64[us]

# %%
ebola_dict={}
for idx, col in enumerate(ebola):
    d=shift_values[idx].days
    shifted=ebola[col].shift(d)
    ebola_dict[col]=shifted
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 3
#       1 ebola_dict={}
#       2 for idx, col in enumerate(ebola):
# ----> 3     d=shift_values[idx].days
#       4     shifted=ebola[col].shift(d)
#       5     ebola_dict[col]=shifted
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
#     961 # Convert generator to list before going through hashable part
#     962 # (We will iterate through the generator there to check for slices)
#     963 if is_iterator(key):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1046, in Series._get_value(self, label, takeable)
#    1043     return self._values[label]
#    1045 # Similar to Index.get_value, but we do not fall back to positional
# -> 1046 loc = self.index.get_loc(label)
#    1048 if is_integer(loc):
#    1049     return self._values[loc]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 0

# %%
ebola_shift=pd.DataFrame(ebola_dict)

# %%
print(ebola_shift.tail())
# Out:
# Empty DataFrame
# Columns: []
# Index: []
