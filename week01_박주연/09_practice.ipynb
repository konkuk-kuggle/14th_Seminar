# %% [markdown]
# # 문자열 추출하기

# %%
word = 'grail'
sent = 'a scratch'

print(word[0])
print(sent[0])
print(word[0:3])
print(sent[-1])
print(sent[-9:-8])
print(sent[0:-8])
# Out:
# g
# a
# gra
# h

# %%
print(sent[2:-1])
print(sent[-7:-1])

s_len=len(sent)
print(s_len)
print(sent[2:s_len])
# Out:
# scratc
# scratc
# 9
# scratch

# %% [markdown]
# # 왼쪽이나 오른쪽 범위를 지정하지 않고 문자열 추출하기

# %%
print(word[0:3])
print(word[:3])
print(sent[2:len(sent)])
print(sent[2:1])
print(sent[:])
print(sent[::2])

# %% [markdown]
# # join, splitlines, replace 메서드 실습하기

# %%
d1 = '40'
m1 = "46'"
s1 = '52.837"'
u1 = 'N'

d2='73'
m2="58'"
s2='26.302"'
u2='W'

coords = ''.join([d1, m1, s1, u1, d2, m2, s2, u2])
print(coords)
print()
coords = '   '.join([d1, m1, s1, u1, d2, m2, s2, u2])
print(coords)
# Out:
# 4046'52.837"N7358'26.302"W
#
# 40   46'   52.837"   N   73   58'   26.302"   W

# %%
multi_str="""Guard: What? Ridden on a hore?
King Arthur: Yes!
Guard: You're using coconuts!
King Arthur: what?
Guard: you've got ... coconut[s] and you're bangin' 'em together.
"""

print(multi_str)

multi_str_split = multi_str.splitlines()
print(multi_str_split)

guard=multi_str_split[::2]
print(guard)

guard=multi_str.replace("Guard: ","").splitlines()[::2]
print(guard)
# Out:
# Guard: What? Ridden on a hore?
# King Arthur: Yes!
# Guard: You're using coconuts!
# King Arthur: what?
# Guard: you've got ... coconut[s] and you're bangin' 'em together.
#
# ['Guard: What? Ridden on a hore?', 'King Arthur: Yes!', "Guard: You're using coconuts!", 'King Arthur: what?', "Guard: you've got ... coconut[s] and you're bangin' 'em together."]
# ['Guard: What? Ridden on a hore?', "Guard: You're using coconuts!", "Guard: you've got ... coconut[s] and you're bangin' 'em together."]
# ['What? Ridden on a hore?', "You're using coconuts!", "you've got ... coconut[s] and you're bangin' 'em together."]

# %% [markdown]
# # 문자열 포매팅 실습하기

# %%
s="It's just a {}!"
var='flesh wound'

print(s.format(var))
print(s.format('scratch'))
# Out:
# It's just a flesh wound!
# It's just a scratch!

# %%
s = """black knight: 'tis but a {0}.
king arthur: A {0}? your arm's off!
"""

print(s.format('scratch'))
# Out:
# black knight: 'tis but a scratch.
# king arthur: A scratch? your arm's off!

# %%
s = 'hayden planetarium coordinates: {lat}, {lon}'
print(s.format(lat='40.7815 N', lon='73.97444 W'))
# Out:
# hayden planetarium coordinates: 40.7815 N, 73.97444 W

# %% [markdown]
# # 수치값 포매팅 실습

# %%
print('Some digits of pi: {}'.format(3.141592))
print("In 2005, Lu Chao of China recited {:,} digits of pi".format(67890))
print("I remember {0:.4} or {0:4%} of what Lu Chao recited".format(7/67890))
print("My ID number is {0:05d}".format(42))
# Out:
# Some digits of pi: 3.141592
# In 2005, Lu Chao of China recited 67,890 digits of pi
# I remember 0.0001031 or 0.010311% of what Lu Chao recited
# My ID number is 00042

# %% [markdown]
# # % 연산자로 포매팅하기

# %%
s= 'I only know %d digits of pi'%7
print(s)
print('Some digits of %(cont)s: %(value).2f'%{'cont': 'e', 'value':2.718})
# Out:
# I only know 7 digits of pi
# Some digits of e: 2.72

# %% [markdown]
# # f-strings로 포매팅 사용하기

# %%
var='flesh wound'
s=f"It's kist a {var}!"
print(s)

lat='40.7815N'
lon='73.9733W'
s= f'Hayden Plaetatun Coordinats:{lat}, {lon}'
print(s)
# Out:
# It's kist a flesh wound!

# %% [markdown]
# # 정규식으로 전화번호 패턴 찾기

# %%
import re
tele_num = '1234567890'
m=re.match(pattern='\d\d\d\d\d\d\d\d\d\d', string=tele_num)
print(type(m))
print(m)
# Out:
# <class 're.Match'>
# <re.Match object; span=(0, 10), match='1234567890'>

# %%
print(bool(m))
if m:
    print('match')
else:
    print('no match')
# Out:
# True
# match

# %%
print(m.start())
print(m.end())
print(m.span())
print(m.group())
# Out:
# 0
# 10
# (0, 10)
# 1234567890

# %%
tele_num_spaces = '123 456 7890'
m= re.match(pattern = '\d{10}', string=tele_num_spaces)
print(m)

if m:
    print('match')
else:
    print('no match')
# Out:
# None
# no match

# %%
p = '\d{3}\s?\d{3}\s?\d{4}'
m = re.match(pattern=p, string=tele_num_spaces)
print(m)
# Out:
# <re.Match object; span=(0, 12), match='123 456 7890'>

# %%
tele_num_space_paren_dash = '(123) 456-7890' 
p = '\(?\d{3}\)?\s?\d{3}\s?-?\d{4}'
m = re.match(pattern=p, string=tele_num_space_paren_dash)
print(m)
print()
cnty_tele_num_space_paren_dash = '+1 (123) 456-7890' 
p = '\+1?\s?\(?\d{3}\)?\s?\d{3}\s?-?\d{4}'
m = re.match(pattern=p, string=cnty_tele_num_space_paren_dash)
print(m)
# Out:
# <re.Match object; span=(0, 14), match='(123) 456-7890'>
#
# <re.Match object; span=(0, 17), match='+1 (123) 456-7890'>

# %% [markdown]
# # compile 메서드로 정규식 메서드 사용하기

# %%
p = re.compile('/d{10}')
s = '1234567890'
m = p.match(s)
print(m)
# Out:
# None
