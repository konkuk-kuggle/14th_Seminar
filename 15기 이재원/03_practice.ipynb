# %% [markdown]
# # 시리즈 만들기

# %%
import pandas as pd
s = pd.Series(['banana',42])
print(s)

s = pd.Series(['Wes McKinney','Creator of Pandas'])
print(s)

s = pd.Series(['Wes McKinney','Creator of Pandas'], index=['Person','Who'])
print(s)
# Out:
# 0    banana
# 1        42
# dtype: object
# 0         Wes McKinney
# 1    Creator of Pandas
# dtype: str
# Person         Wes McKinney
# Who       Creator of Pandas
# dtype: str

# %% [markdown]
# # 데이터프레임 만들기

# %%
scientists = pd.DataFrame({
    'Name' : ['Rosaline Framklin','William Gosset'],
    'Occupation' : ['Chemist','Statistician'],
    'Born' : ['1920-07-25','1876-06-13'],
    'Died' : ['1958-04-16','1937-10-16'],
    'Age' : [37,61]}
)
print(scientists)

scientists = pd.DataFrame(
    data={
    'Occupation' : ['Chemist','Statistician'],
    'Born' : ['1920-07-25','1876-06-13'],
    'Died' : ['1958-04-16','1937-10-16'],
    'Age' : [37,61]},
    index=['Rosaline Framklin','William Gosset'],
    columns=['Occupation','Born','Age','Died']
)
print(scientists)

from collections import OrderedDict
scientists = pd.DataFrame(OrderedDict([
    ('Name', ['Rosaline Framklin','William Gosset']),
    ('Occupation' , ['Chemist','Statistician']),
    ('Born' , ['1920-07-25','1876-06-13']),
    ('Died' , ['1958-04-16','1937-10-16']),
    ('Age' , [37,61])
                          ])
)
print(scientists)
# Out:
#                 Name    Occupation        Born        Died  Age
# 0  Rosaline Framklin       Chemist  1920-07-25  1958-04-16   37
# 1     William Gosset  Statistician  1876-06-13  1937-10-16   61
#                      Occupation        Born  Age        Died
# Rosaline Framklin       Chemist  1920-07-25   37  1958-04-16
# William Gosset     Statistician  1876-06-13   61  1937-10-16
#                 Name    Occupation        Born        Died  Age
# 0  Rosaline Framklin       Chemist  1920-07-25  1958-04-16   37
# 1     William Gosset  Statistician  1876-06-13  1937-10-16   61

# %% [markdown]
# # 데이터프레임에서 시리즈 선택하기

# %%
import pandas as pd
scientists = pd.DataFrame(
    data={
    'Occupation' : ['Chemist','Statistician'],
    'Born' : ['1920-07-25','1876-06-13'],
    'Died' : ['1958-04-16','1937-10-16'],
    'Age' : [37,61]},
    index=['Rosaline Framklin','William Gosset'],
    columns=['Occupation','Born','Died','Age']
)

first_row = scientists.loc['William Gosset']
print(type(first_row))
print(first_row)
# Out:
# <class 'pandas.Series'>
# Occupation    Statistician
# Born            1876-06-13
# Died            1937-10-16
# Age                     61
# Name: William Gosset, dtype: object

# %% [markdown]
# # index, values, keys 사용하기

# %%
print(first_row.index)

print(first_row.values)
print(first_row.keys())

print(first_row.index[0])

print(first_row.keys()[0])
# Out:
# Index(['Occupation', 'Born', 'Died', 'Age'], dtype='str')
# ['Statistician' '1876-06-13' '1937-10-16' np.int64(61)]
# Index(['Occupation', 'Born', 'Died', 'Age'], dtype='str')
# Occupation
# Occupation

# %% [markdown]
# # 시리즈의 mean, min, max, std 메서드 사용하기

# %%
ages = scientists['Age']
print(ages)
print(ages.mean())
print(ages.min())
print(ages.max())
print(ages.std())
# Out:
# Rosaline Framklin    37
# William Gosset       61
# Name: Age, dtype: int64
# 49.0
# 37
# 61
# 16.97056274847714

# %% [markdown]
# # 시리즈와 불린 추출 사용하기

# %%
scientists = pd.read_csv('../data/scientists.csv')

ages = scientists['Age']
print(ages.max())
print(ages.mean())

print(ages[ages>ages.mean()])
print(ages>ages.mean())
print(type(ages>ages.mean()))

manual = [True,True, False, False, True, True,False, True]
print(ages[manual])
# Out:
# 90
# 59.125
# 1    61
# 2    90
# 3    66
# 7    77
# Name: Age, dtype: int64
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# Name: Age, dtype: bool
# <class 'pandas.Series'>
# 0    37
# 1    61
# 4    56
# 5    45
# 7    77
# Name: Age, dtype: int64

# %% [markdown]
# # 시리즈와 브로드캐스팅

# %%
print(ages + ages)
print(ages*ages)
print(ages + 100)
print(ages*2)
print(pd.Series([1,100]))
print(ages + pd.Series([1,100]))

rev_ages= ages.sort_index(ascending=False)
print(rev_ages)
print(ages+rev_ages)
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64
# 0    1369
# 1    3721
# 2    8100
# 3    4356
# 4    3136
# 5    2025
# 6    1681
# 7    5929
# Name: Age, dtype: int64
# 0    137
# 1    161
# 2    190
# 3    166
# 4    156
# 5    145
# 6    141
# 7    177
# Name: Age, dtype: int64
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64
# 0      1
# 1    100
# dtype: int64
# 0     38.0
# 1    161.0
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# dtype: float64
# 7    77
# 6    41
# 5    45
# 4    56
# 3    66
# 2    90
# 1    61
# 0    37
# Name: Age, dtype: int64
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %% [markdown]
# # 데이터프레임과 불린 추출

# %%
print(scientists[scientists['Age'] > scientists['Age'].mean()])
print(scientists.loc[[True,True,False,True]])
# Out:
#                    Name        Born        Died  Age     Occupation
# 1        William Gosset  1876-06-13  1937-10-16   61   Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 print(scientists[scientists['Age'] > scientists['Age'].mean()])
# ----> 2 print(scientists.loc[[True,True,False,True]])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429     return self._get_slice_axis(key, axis=axis)
#    1430 elif com.is_bool_indexer(key):
# -> 1431     return self._getbool_axis(key, axis=axis)
#    1432 elif is_list_like_indexer(key):
#    1433     # an iterable multi-selection
#    1434     if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1225, in _LocationIndexer._getbool_axis(self, key, axis)
#    1221 @final
#    1222 def _getbool_axis(self, key, axis: AxisInt):
#    1223     # caller is responsible for ensuring non-None axis
#    1224     labels = self.obj._get_axis(axis)
# -> 1225     key = check_bool_indexer(labels, key)
#    1226     inds = key.nonzero()[0]
#    1227     return self.obj.take(inds, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:2696, in check_bool_indexer(index, key)
#    2692 elif not is_array_like(result):
#    2693     # GH 33924
#    2694     # key may contain nan elements, check_array_indexer needs bool array
#    2695     result = pd_array(result, dtype=bool)
# -> 2696 return check_array_indexer(index, result)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexers\utils.py:570, in check_array_indexer(array, indexer)
#     568     # GH26658
#     569     if len(indexer) != len(array):
# --> 570         raise IndexError(
#     571             f"Boolean index has wrong length: "
#     572             f"{len(indexer)} instead of {len(array)}"
#     573         )
#     574 elif is_integer_dtype(dtype):
#     575     try:
#
# IndexError: Boolean index has wrong length: 4 instead of 8

# %% [markdown]
# # 데이터프레임과 브로드캐스팅

# %%
print(scientists*2)

# %% [markdown]
# # 열의 자료형 바꾸기와 새로운 열 추가하기

# %%
print(scientists['Born'].dtype)
print(scientists['Died'].dtype)

born_datetime = pd.to_datetime(scientists['Born'], format='%Y-%m-%d')
print(born_datetime)

died_datetime = pd.to_datetime(scientists['Died'], format='%Y-%m-%d')
print(died_datetime)

scientists['born_dt'], scientists['died_dt'] = (born_datetime, died_datetime)
print(scientists.head())

print(scientists.shape)
scientists['age_days_dt'] = (scientists['died_dt'] - scientists['born_dt'])
print(scientists)
# Out:
# str
# str
# 0   1920-07-25
# 1   1876-06-13
# 2   1820-05-12
# 3   1867-11-07
# 4   1907-05-27
# 5   1813-03-15
# 6   1912-06-23
# 7   1777-04-30
# Name: Born, dtype: datetime64[us]
# 0   1958-04-16
# 1   1937-10-16
# 2   1910-08-13
# 3   1934-07-04
# 4   1964-04-14
# 5   1858-06-16
# 6   1954-06-07
# 7   1855-02-23
# Name: Died, dtype: datetime64[us]
#                    Name        Born        Died  Age    Occupation    born_dt  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37       Chemist 1920-07-25
# 1        William Gosset  1876-06-13  1937-10-16   61  Statistician 1876-06-13
# 2  Florence Nightingale  1820-05-12  1910-08-13   90         Nurse 1820-05-12
# 3           Marie Curie  1867-11-07  1934-07-04   66       Chemist 1867-11-07
# 4         Rachel Carson  1907-05-27  1964-04-14   56     Biologist 1907-05-27
#
#      died_dt
# 0 1958-04-16
# 1 1937-10-16
# 2 1910-08-13
# 3 1934-07-04
# 4 1964-04-14
# (8, 7)
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#      born_dt    died_dt age_days_dt
# 0 1920-07-25 1958-04-16  13779 days
# 1 1876-06-13 1937-10-16  22404 days
# 2 1820-05-12 1910-08-13  32964 days
# 3 1867-11-07 1934-07-04  24345 days
# 4 1907-05-27 1964-04-14  20777 days
# 5 1813-03-15 1858-06-16  16529 days
# 6 1912-06-23 1954-06-07  15324 days
# 7 1777-04-30 1855-02-23  28422 days

# %% [markdown]
# # 시리즈, 데이터프레임의 데이터 섞어보기

# %%
print(scientists['Age'])

import random
random.seed(42)
random.shuffle(scientists['Age'])
print(scientists['Age'])
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64

# %% [markdown]
# # 데이터프레임의 열 삭제하기

# %%
print(scientists.columns)

scientists_dropped = scientists.drop(['Age'], axis=1)
print(scientists_dropped.columns)
# Out:
# Index(['Name', 'Born', 'Died', 'Age', 'Occupation', 'born_dt', 'died_dt',
#        'age_days_dt'],
#       dtype='str')
# Index(['Name', 'Born', 'Died', 'Occupation', 'born_dt', 'died_dt',
#        'age_days_dt'],
#       dtype='str')

# %% [markdown]
# # 피클 형식으로 저장하기

# %%
names = scientists['Name']
names.to_pickle('../output/scientists_names_series.pickle')

scientists.to_pickle('../output/scientists_df.pickle')

scientist_names_from_pickle = pd.read_pickle('../output/scientists_names_series.pickle')
print(scientist_names_from_pikcle)

scientist_from_pickle = pd.read_pickle('../output/scientists_df.pickle')
print(scientis_from_pikcle)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 7
#       3
#       4 scientists.to_pickle('../output/scientists_df.pickle')
#       5
#       6 scientist_names_from_pickle = pd.read_pickle('../output/scientists_names_series.pickle')
# ----> 7 print(scientist_names_from_pikcle)
#       8
#       9 scientist_from_pickle = pd.read_pickle('../output/scientists_df.pickle')
#      10 print(scientis_from_pikcle)
#
# NameError: name 'scientist_names_from_pikcle' is not defined

# %% [markdown]
# # CSV 불러오기

# %%
names.to_csv(../output/scientists_names_series.csv')
scientists.to_csv('../output/scientists_df.tsv',sep='\t')

names_df = names.to_frame()

improt xlwt
names_df.to_excel('../output/scientists_names_series_df.xls')

import openpyxl
names_df.to_excel(''../output/scientists_names_series_df.xlsx')
# Out:
#   Cell In[19], line 1
#     names.to_csv(../output/scientists_names_series.csv')
#                                                       ^
# SyntaxError: unterminated string literal (detected at line 1)
