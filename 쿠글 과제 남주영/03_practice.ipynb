# %% [markdown]
# # 시리즈 만들기

# %%
import pandas as pd
s= pd.Series(['banana',42])
print(s)
# Out:
# 0    banana
# 1        42
# dtype: object

# %%
s=pd.Series(['Wes McKinney', 'Creator of Pandas'])
print(s)
# Out:
# 0         Wes McKinney
# 1    Creator of Pandas
# dtype: str

# %%
s=pd.Series(['Wes McKinney', 'Creator of Pandas'], index=['Person', 'Who'])
print(s)
# Out:
# Person         Wes McKinney
# Who       Creator of Pandas
# dtype: str

# %%
scientists=pd.DataFrame({
    'Name':['Rosaline Franklin', 'william Gosset'],
    'Occupation': ['Chemist', 'Statistician'],
    'Born': ['1920-07-25', '1879-06-13'],
    'Died': ['1958-04-16', '1937-10-16'],
    'Age':[37, 61]})
print(scientists)
# Out:
#                 Name    Occupation        Born        Died  Age
# 0  Rosaline Franklin       Chemist  1920-07-25  1958-04-16   37
# 1     william Gosset  Statistician  1879-06-13  1937-10-16   61

# %%
scientists=pd.DataFrame(
    data={'Occupation':['Chemist', 'Statistician'],
         'Born':['1029-07-25', '1876-06-13'],
    'Age': [37,61]},
index=['Rosaline Franklin', 'William Gosset'],
columns=['Occupation', 'Born', 'Age', 'Died']
)
print(scientists)
# Out:
#                      Occupation        Born  Age Died
# Rosaline Franklin       Chemist  1029-07-25   37  NaN
# William Gosset     Statistician  1876-06-13   61  NaN

# %%
from collections import OrderedDict

scientist=pd.DataFrame(OrderedDict([
    ('Name', ['Rosaline Franklin', 'willwam GGosset']),
    ('Occupation', ['Chemist', 'Statistcian']),
    ('Born', ['1920-07-25', '1876-06-13']),
    ('Died', ['1958-94-16', '1937-10-16']),
    ('Age', [37, 61])
]))
print(scientists)
# Out:
#                      Occupation        Born  Age Died
# Rosaline Franklin       Chemist  1029-07-25   37  NaN
# William Gosset     Statistician  1876-06-13   61  NaN

# %%
scientists=pd.DataFrame(
    data={'Occupation': ['Chemist', 'Statistician'],
         'Born':['1920-07-25', '1876-06-13'],
         'Died':['1958-04-16', '1937-10-16'],
         'Age': [37, 61]},
    index=['Rosaline Frankline', 'william Gosset'],
    columns=['Occupation', 'Born', 'Died', 'Age'])

# %%
first_row = scientists.loc['william Gosset']
print(type(first_row))
# Out:
# <class 'pandas.Series'>

# %%
print(first_row)
# Out:
# Occupation    Statistician
# Born            1876-06-13
# Died            1937-10-16
# Age                     61
# Name: william Gosset, dtype: object

# %% [markdown]
# # index, values, keys 사용하기

# %%
print(first_row.index)
# Out:
# Index(['Occupation', 'Born', 'Died', 'Age'], dtype='str')

# %%
print(first_row.values)
# Out:
# ['Statistician' '1876-06-13' '1937-10-16' np.int64(61)]

# %%
print(first_row.keys())
# Out:
# Index(['Occupation', 'Born', 'Died', 'Age'], dtype='str')

# %%
print(first_row.index[0])
# Out:
# Occupation

# %%
print(first_row.keys()[0])
# Out:
# Occupation

# %% [markdown]
# # 시리즈의 mean, min, max, std 메서드 사용하기

# %%
ages= scientists['Age']
print(ages)
# Out:
# Rosaline Frankline    37
# william Gosset        61
# Name: Age, dtype: int64

# %%
print(ages.mean())
# Out:
# 49.0

# %%
print(ages.min())
# Out:
# 37

# %%
print(ages.max())
# Out:
# 61

# %%
print(ages.std())
# Out:
# 16.97056274847714

# %%
scientists=pd.read_csv('../data/scientists.csv')

# %%
ages=scientists['Age']
print(ages.max())
# Out:
# 90

# %%
print(ages.mean())
# Out:
# 59.125

# %%
print(ages[ages>ages.mean()])
# Out:
# 1    61
# 2    90
# 3    66
# 7    77
# Name: Age, dtype: int64

# %%
print(ages>ages.mean())
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# Name: Age, dtype: bool

# %%
print(type(ages>ages.mean()))
# Out:
# <class 'pandas.Series'>

# %%
manual_bool_values= [True, True, False, False, True, True, False, True]
print(ages[manual_bool_values])
# Out:
# 0    37
# 1    61
# 4    56
# 5    45
# 7    77
# Name: Age, dtype: int64

# %% [markdown]
# # 시리즈와 브로드캐스팅

# %%
print(ages+ages)
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %%
print(ages*ages)
# Out:
# 0    1369
# 1    3721
# 2    8100
# 3    4356
# 4    3136
# 5    2025
# 6    1681
# 7    5929
# Name: Age, dtype: int64

# %%
print(ages+100)
# Out:
# 0    137
# 1    161
# 2    190
# 3    166
# 4    156
# 5    145
# 6    141
# 7    177
# Name: Age, dtype: int64

# %%
print(ages*2)
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %%
print(pd.Series([1,100]))
# Out:
# 0      1
# 1    100
# dtype: int64

# %%
print(ages+pd.Series([1,100]))
# Out:
# 0     38.0
# 1    161.0
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# dtype: float64

# %%
rev_ages= ages.sort_index(ascending=False)
print(rev_ages)
# Out:
# 7    77
# 6    41
# 5    45
# 4    56
# 3    66
# 2    90
# 1    61
# 0    37
# Name: Age, dtype: int64

# %%
print(ages*2)
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %%
print(ages+ rev_ages)
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %% [markdown]
# # 데이터프레임과 불린 추출

# %%
print(scientists[scientists['Age']> scientists['Age'].mean()])
# Out:
#                    Name        Born        Died  Age     Occupation
# 1        William Gosset  1876-06-13  1937-10-16   61   Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
print(scientists.loc[[0,1,3]])
# Out:
#                 Name        Born        Died  Age    Occupation
# 0  Rosaline Franklin  1920-07-25  1958-04-16   37       Chemist
# 1     William Gosset  1876-06-13  1937-10-16   61  Statistician
# 3        Marie Curie  1867-11-07  1934-07-04   66       Chemist

# %% [markdown]
# # 데이터프레임과 브로드캐스팅

# %%
print(scientists*2)
# Out:
#                                        Name                  Born  \
# 0        Rosaline FranklinRosaline Franklin  1920-07-251920-07-25
# 1              William GossetWilliam Gosset  1876-06-131876-06-13
# 2  Florence NightingaleFlorence Nightingale  1820-05-121820-05-12
# 3                    Marie CurieMarie Curie  1867-11-071867-11-07
# 4                Rachel CarsonRachel Carson  1907-05-271907-05-27
# 5                        John SnowJohn Snow  1813-03-151813-03-15
# 6                    Alan TuringAlan Turing  1912-06-231912-06-23
# 7                  Johann GaussJohann Gauss  1777-04-301777-04-30
#
#                    Died  Age                            Occupation
# 0  1958-04-161958-04-16   74                        ChemistChemist
# 1  1937-10-161937-10-16  122              StatisticianStatistician
# 2  1910-08-131910-08-13  180                            NurseNurse
# 3  1934-07-041934-07-04  132                        ChemistChemist
# ...

# %% [markdown]
# # 열의 자료형 바꾸기와 새로운 열 추가하기

# %%
print(scientists['Born'].dtype)
# Out:
# str

# %%
print(scientists['Died'].dtype)
# Out:
# str

# %%
born_datetime= pd.to_datetime(scientists['Born'], format='%Y-%m-%d')
print(born_datetime)
# Out:
# 0   1920-07-25
# 1   1876-06-13
# 2   1820-05-12
# 3   1867-11-07
# 4   1907-05-27
# 5   1813-03-15
# 6   1912-06-23
# 7   1777-04-30
# Name: Born, dtype: datetime64[us]

# %% [raw]
# died_datetime=pd.to_datetime(scientists['Died'], format='%Y-%m-%d')
#
# print(died_datetime)

# %%
scientists['born_dt'], scientists['died_dt']= (born_datetime, died_datetime)
print(scientists.head( ))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 scientists['born_dt'], scientists['died_dt']= (born_datetime, died_datetime)
#       2 print(scientists.head( ))
#
# NameError: name 'died_datetime' is not defined

# %% [raw]
# print(scientists.shape)

# %%
scientists['age_days_dt']= (scientists['died_dt']- scientists['born_dt'])
print(scientists)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# ...

# %% [markdown]
# # 시리즈, 데이터프레임의 데이터 섞어보기

# %%
print(scientists['Age'])
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64

# %%
import random
random.seed(42)
random.shuffle(scientists['Age'])
print(scientists['Age'])
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64

# %% [markdown]
# # 데이터프레임의 열 삭제하기

# %%
print(scientists.columns)
# Out:
# Index(['Name', 'Born', 'Died', 'Age', 'Occupation'], dtype='str')

# %%
scientists_dropped=scientists.drop(['Age'], axis=1)
print(scientists_dropped.columns)
# Out:
# Index(['Name', 'Born', 'Died', 'Occupation'], dtype='str')

# %% [markdown]
# # 피클 형식으로 저장하기

# %%
names= scientists['Name']
names.to_pickie('../output/scientists_names_series.pickle')
scientiststo_pickle('../output/scientists_df.pickle')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[75], line 2
#       1 names= scientists['Name']
# ----> 2 names.to_pickie('../output/scientists_names_series.pickle')
#       3 scientiststo_pickle('../output/scientists_df.pickle')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6199 if (
#    6200     name not in self._internal_names_set
#    6201     and name not in self._metadata
#    6202     and name not in self._accessors
#    6203     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204 ):
#    6205     return self[name]
# -> 6206 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'to_pickie'

# %%
scientist_names_form_pickle=pd.read_pickle('../output/scientists_df.pickle')
print(scientists_form_pickle)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 2
#       1 scientist_names_form_pickle=pd.read_pickle('../output/scientists_df.pickle')
# ----> 2 print(scientists_form_pickle)
#
# NameError: name 'scientists_form_pickle' is not defined

# %% [markdown]
# # CSV 불러오기

# %%
names.to_csv('../output/scientists_names_series.csv')
scientists.to__csv('../output/scientists_df.tsv', sep='\t')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 2
#       1 names.to_csv('../output/scientists_names_series.csv')
# ----> 2 scientists.to__csv('../output/scientists_df.tsv', sep='\t')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6199 if (
#    6200     name not in self._internal_names_set
#    6201     and name not in self._metadata
#    6202     and name not in self._accessors
#    6203     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204 ):
#    6205     return self[name]
# -> 6206 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to__csv'
