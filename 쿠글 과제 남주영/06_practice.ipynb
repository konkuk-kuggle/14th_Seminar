# %% [markdown]
# # 누락값 확인하기

# %%
from numpy import NaN, NAN, nan
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from numpy import NaN, NAN, nan
#
# ImportError: cannot import name 'NaN' from 'numpy' (C:\Users\namju\anaconda3\Lib\site-packages\numpy\__init__.py)

# %%
print(NaN == True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(NaN == True)
#
# NameError: name 'NaN' is not defined

# %%
print(NaN == False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(NaN == False)
#
# NameError: name 'NaN' is not defined

# %%
print(NaN == 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(NaN == 0)
#
# NameError: name 'NaN' is not defined

# %%
print(NaN == '')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(NaN == '')
#
# NameError: name 'NaN' is not defined

# %%
print(NaN == NaN)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(NaN == NaN)
#
# NameError: name 'NaN' is not defined

# %%
print(NaN == nan)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(NaN == nan)
#
# NameError: name 'NaN' is not defined

# %%
print(NaN == NAN)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(NaN == NAN)
#
# NameError: name 'NaN' is not defined

# %%
print(nan == NAN)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print(nan == NAN)
#
# NameError: name 'nan' is not defined

# %% [markdown]
# # 누락값을 포함한 데이터를 불러올 때

# %%
import pandas as pd 

print(pd.isnull(NaN))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 import pandas as pd
#       2
# ----> 3 print(pd.isnull(NaN))
#
# NameError: name 'NaN' is not defined

# %% [markdown]
# # 데이터 집합을 연결할 때 누락값이 발생하는 경우

# %%
visited = pd.read_csv('../data/survey_visited.csv') 
survey = pd.read_csv('../data/survey_survey.csv')

print(visited)

# %%
print(survey)

# %%
vs = visited.merge(survey, left_on='ident', right_on='taken') 
print(vs)

# %% [markdown]
# # 데이터를 입력할 때 누락값이 발생하는 경우

# %%
num_legs = pd.Series({'goat': 4, 'amoeba': nan}) 
print(num_legs)
print(type(num_legs))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 num_legs = pd.Series({'goat': 4, 'amoeba': nan})
#       2 print(num_legs)
#       3 print(type(num_legs))
#
# NameError: name 'nan' is not defined

# %%
scientists = pd.DataFrame({ 
    'Name': ['Rosaline Franklin', 'William Gosset'], 
    'Occupation': ['Chemist', 'Statistician'], 
    'Born': ['1920-07-25', '1876-06-13'], 
    'Died': ['1958-04-16', '1937-10-16'], 
    'missing': [NaN, nan]}) 

print(scientists)
print(type(scientists))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 6
#       2     'Name': ['Rosaline Franklin', 'William Gosset'],
#       3     'Occupation': ['Chemist', 'Statistician'],
#       4     'Born': ['1920-07-25', '1876-06-13'],
#       5     'Died': ['1958-04-16', '1937-10-16'],
# ----> 6     'missing': [NaN, nan]})
#       7
#       8 print(scientists)
#       9 print(type(scientists))
#
# NameError: name 'NaN' is not defined

# %% [markdown]
# # 인덱스를 다시 만들 때 누락값이 발생하는 경우

# %%
gapminder = pd.read_csv('../data/gapminder.tsv', sep='\t')

# %%
life_exp = gapminder.groupby(['year'])['lifeExp'].mean() 
print(life_exp)
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
print(life_exp.loc[range(2000, 2010), ])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print(life_exp.loc[range(2000, 2010), ])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#    1203     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1386, in _LocIndexer._getitem_tuple(self, tup)
#    1384 with suppress(IndexingError):
#    1385     tup = self._expand_ellipsis(tup)
# -> 1386     return self._getitem_lowerdim(tup)
#    1388 # no multi-index, so validate all of the indexers
#    1389 tup = self._validate_tuple_indexer(tup)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1093, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1089 for i, key in zip(range(len(tup) - 1, -1, -1), reversed(tup), strict=True):
#    1090     if is_label_like(key) or is_list_like(key):
#    1091         # We don't need to check for tuples here because those are
#    1092         #  caught by the _is_nested_tuple_indexer check above.
# -> 1093         section = self._getitem_axis(key, axis=i)
#    1095         # We should never have a scalar section here, because
#    1096         #  _getitem_lowerdim is only called after a check for
#    1097         #  is_scalar_access, which that would be.
#    1098         if section.ndim == self.ndim:
#    1099             # we're in the middle of slicing through a MultiIndex
#    1100             # revise the key wrt to `section` by inserting an _NS
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1438, in _LocIndexer._getitem_axis(self, key, axis)
#    1435     if hasattr(key, "ndim") and key.ndim > 1:
#    1436         raise ValueError("Cannot index with multidimensional key")
# -> 1438     return self._getitem_iterable(key, axis=axis)
#    1440 # nested tuple slicing
#    1441 if is_nested_tuple(key, labels):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1378, in _LocIndexer._getitem_iterable(self, key, axis)
#    1375 self._validate_key(key, axis)
#    1377 # A collection of keys
# -> 1378 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1379 return self.obj._reindex_with_indexers(
#    1380     {axis: [keyarr, indexer]}, allow_dups=True
#    1381 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1576, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1573 ax = self.obj._get_axis(axis)
#    1574 axis_name = self.obj._get_axis_name(axis)
# -> 1576 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1578 return keyarr, indexer
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6355, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6352     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6355 raise KeyError(f"{not_found} not in index")
#
# KeyError: '[2000, 2001, 2003, 2004, 2005, 2006, 2008, 2009] not in index'

# %%
y2000 = life_exp[life_exp.index > 2000] 
print(y2000)

# %% [markdown]
# # 누락값의 개수 구하기

# %%
ebola = pd.read_csv('../data/country_timeseries.csv')

# %%
print(ebola.count())
# Out:
# Date                   122
# Day                    122
# Cases_Guinea            93
# Cases_Liberia           83
# Cases_SierraLeone       87
# Cases_Nigeria           38
# Cases_Senegal           25
# Cases_UnitedStates      18
# Cases_Spain             16
# Cases_Mali              12
# Deaths_Guinea           92
# Deaths_Liberia          81
# Deaths_SierraLeone      87
# Deaths_Nigeria          38
# Deaths_Senegal          22
# Deaths_UnitedStates     18
# Deaths_Spain            16
# Deaths_Mali             12
# dtype: int64

# %%
num_rows = ebola.shape[0]
num_missing = num_rows - ebola.count() 
print(num_missing)
# Out:
# Date                     0
# Day                      0
# Cases_Guinea            29
# Cases_Liberia           39
# Cases_SierraLeone       35
# Cases_Nigeria           84
# Cases_Senegal           97
# Cases_UnitedStates     104
# Cases_Spain            106
# Cases_Mali             110
# Deaths_Guinea           30
# Deaths_Liberia          41
# Deaths_SierraLeone      35
# Deaths_Nigeria          84
# Deaths_Senegal         100
# Deaths_UnitedStates    104
# Deaths_Spain           106
# Deaths_Mali            110
# dtype: int64

# %%
import numpy as np 

print(np.count_nonzero(ebola.isnull()))
# Out:
# 1214

# %%
print(np.count_nonzero(ebola['Cases_Guinea'].isnull()))
# Out:
# 29

# %%
print(ebola.Cases_Guinea.value_counts(dropna=False).head())
# Out:
# Cases_Guinea
# NaN      29
# 86.0      3
# 495.0     2
# 390.0     2
# 112.0     2
# Name: count, dtype: int64

# %% [markdown]
# # 누락값을 다른 값으로 변경하기

# %%
print(ebola.fillna(0).iloc[0:10, 0:5])
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 0    1/5/2015  289        2776.0            0.0            10030.0
# 1    1/4/2015  288        2775.0            0.0             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           0.0         8157.0                0.0
# 4  12/31/2014  284        2730.0         8115.0             9633.0
# 5  12/28/2014  281        2706.0         8018.0             9446.0
# 6  12/27/2014  280        2695.0            0.0             9409.0
# 7  12/24/2014  277        2630.0         7977.0             9203.0
# 8  12/21/2014  273        2597.0            0.0             9004.0
# 9  12/20/2014  272        2571.0         7862.0             8939.0

# %%
print(ebola.fillna(method='ffill').iloc[0:10, 0:5])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 print(ebola.fillna(method='ffill').iloc[0:10, 0:5])
#
# TypeError: NDFrame.fillna() got an unexpected keyword argument 'method'

# %%
print(ebola.fillna(method='bfill').iloc[0:10, 0:5])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 print(ebola.fillna(method='bfill').iloc[0:10, 0:5])
#
# TypeError: NDFrame.fillna() got an unexpected keyword argument 'method'

# %%
print(ebola.interpolate().iloc[0:10, 0:5])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 print(ebola.interpolate().iloc[0:10, 0:5])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:8065, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, **kwargs)
#    8062 limit_direction = missing.infer_limit_direction(limit_direction, method)
#    8064 index = missing.get_interp_index(method, obj.index)
# -> 8065 new_data = obj._mgr.interpolate(
#    8066     method=method,
#    8067     index=index,
#    8068     limit=limit,
#    8069     limit_direction=limit_direction,
#    8070     limit_area=limit_area,
#    8071     inplace=inplace,
#    8072     **kwargs,
#    8073 )
#    8075 result = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    8076 if should_transpose:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:541, in BaseBlockManager.interpolate(self, inplace, **kwargs)
#     540 def interpolate(self, inplace: bool, **kwargs) -> Self:
# --> 541     return self.apply("interpolate", inplace=inplace, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:445, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     443         applied = b.apply(f, **kwargs)
#     444     else:
# --> 445         applied = getattr(b, f)(**kwargs)
#     446     result_blocks = extend_blocks(applied, result_blocks)
#     448 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:1404, in Block.interpolate(self, method, index, inplace, limit, limit_direction, limit_area, **kwargs)
#    1401 copy, refs = self._get_refs_and_copy(inplace)
#    1403 # Dispatch to the EA method.
# -> 1404 new_values = self.array_values.interpolate(
#    1405     method=method,
#    1406     axis=self.ndim - 1,
#    1407     index=index,
#    1408     limit=limit,
#    1409     limit_direction=limit_direction,
#    1410     limit_area=limit_area,
#    1411     copy=copy,
#    1412     **kwargs,
#    1413 )
#    1414 data = extract_array(new_values, extract_numpy=True)
#    1415 return [self.make_block_same_class(data, refs=refs)]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\arrow\array.py:2491, in ArrowExtensionArray.interpolate(self, method, axis, index, limit, limit_direction, limit_area, copy, **kwargs)
#    2489 # NB: we return type(self) even if copy=False
#    2490 if not self.dtype._is_numeric:
# -> 2491     raise TypeError(f"Cannot interpolate with {self.dtype} dtype")
#    2493 if (
#    2494     method == "linear"
#    2495     and limit_area is None
#    2496     and limit is None
#    2497     and limit_direction == "forward"
#    2498 ):
#    2499     values = self._pa_array.combine_chunks()
#
# TypeError: Cannot interpolate with str dtype

# %% [markdown]
# # 누락값 삭제하기

# %%
print(ebola.shape)

# %%
ebola_dropna = ebola.dropna() 
print(ebola_dropna.shape)
# Out:
# (1, 18)

# %%
print(ebola_dropna)
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 19  11/18/2014  241        2047.0         7082.0             6190.0
#
#     Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 19           20.0            1.0                 4.0          1.0         6.0
#
#     Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# 19         1214.0          2963.0              1267.0             8.0
#
#     Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  Deaths_Mali
# 19             0.0                  1.0           0.0          6.0

# %% [markdown]
# # 누락값이 포함된 데이터 계산하기

# %%
ebola['Cases_multiple'] = ebola['Cases_Guinea'] + ebola['Cases_Liberia'] + ebola['Cases_SierraLeone']

# %%
ebola_subset = ebola.loc[:, ['Cases_Guinea', 'Cases_Liberia', 'Cases_SierraLeone', 'Cases_multiple']] 
print(ebola_subset.head(n=10))
# Out:
#    Cases_Guinea  Cases_Liberia  Cases_SierraLeone  Cases_multiple
# 0        2776.0            NaN            10030.0             NaN
# 1        2775.0            NaN             9780.0             NaN
# 2        2769.0         8166.0             9722.0         20657.0
# 3           NaN         8157.0                NaN             NaN
# 4        2730.0         8115.0             9633.0         20478.0
# 5        2706.0         8018.0             9446.0         20170.0
# 6        2695.0            NaN             9409.0             NaN
# 7        2630.0         7977.0             9203.0         19810.0
# 8        2597.0            NaN             9004.0             NaN
# 9        2571.0         7862.0             8939.0         19372.0

# %%
print(ebola.Cases_Guinea.sum(skipna = True))
# Out:
# 84729.0

# %%
print(ebola.Cases_Guinea.sum(skipna = False))
# Out:
# nan
